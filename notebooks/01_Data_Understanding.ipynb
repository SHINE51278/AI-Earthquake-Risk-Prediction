# %% [markdown]
# <a href="https://colab.research.google.com/github/SHINE51278/AI-Earthquake-Risk-Prediction/blob/main/notebooks/01_Data_Understanding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
import pandas as pd
import numpy as np

# %%
#Load Dataset
df = pd.read_csv("/content/Eartquakes-1990-2023.csv")

# %%
df.shape #Rows n columns
# Out:
# (253112, 12)

# %%
df.info() # DATA TYPES
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253112 entries, 0 to 253111
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   time          253112 non-null  int64
#  1   place         253112 non-null  object
#  2   status        253112 non-null  object
#  3   tsunami       253112 non-null  int64
#  4   significance  253112 non-null  int64
#  5   data_type     253112 non-null  object
#  6   magnitudo     253112 non-null  float64
#  7   state         253112 non-null  object
#  8   longitude     253112 non-null  float64
#  9   latitude      253112 non-null  float64
#  10  depth         253112 non-null  float64
#  11  date          253112 non-null  object
# dtypes: float64(4), int64(3), object(5)
# memory usage: 23.2+ MB

# %%
df.isnull().sum() # MISSING VALUES
# Out:
# time            0
# place           0
# status          0
# tsunami         0
# significance    0
# data_type       0
# magnitudo       0
# state           0
# longitude       0
# latitude        0
# depth           0
# date            0
# dtype: int64

# %%
df.duplicated().sum() # DUPLICATE RECORDS
# Out:
# np.int64(1309)

# %%
df.columns
# Out:
# Index(['time', 'place', 'status', 'tsunami', 'significance', 'data_type',
#        'magnitudo', 'state', 'longitude', 'latitude', 'depth', 'date'],
#       dtype='object')
